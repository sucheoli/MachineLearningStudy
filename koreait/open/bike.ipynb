# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

bike_df = pd.read_csv('house\data\SeoulBikeData.csv', encoding='CP949')
bike_df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(캜)  Humidity(%)  \
# 0  01/12/2017                254     0            -5.2           37
# 1  01/12/2017                204     1            -5.5           38
# 2  01/12/2017                173     2            -6.0           39
# 3  01/12/2017                107     3            -6.2           40
# 4  01/12/2017                 78     4            -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(캜)  \
# 0               2.2              2000                     -17.6
# 1               0.8              2000                     -17.6
# 2               1.0              2000                     -17.7
# 3               0.9              2000                     -17.6
# 4               2.3              2000                     -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functioning Day
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %%
bike_df.info()

# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype  
# ---  ------                    --------------  -----  
#  0   Date                      8760 non-null   object 
#  1   Rented Bike Count         8760 non-null   int64  
#  2   Hour                      8760 non-null   int64  
#  3   Temperature(캜)            8760 non-null   float64
#  4   Humidity(%)               8760 non-null   int64  
#  5   Wind speed (m/s)          8760 non-null   float64
#  6   Visibility (10m)          8760 non-null   int64  
#  7   Dew point temperature(캜)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)   8760 non-null   float64
#  9   Rainfall(mm)              8760 non-null   float64
#  10  Snowfall (cm)             8760 non-null   float64
#  11  Seasons                   8760 non-null   object 
#  12  Holiday                   8760 non-null   object 
#  13  Functioning Day           8760 non-null   object 
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.2+ KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8760 non-null   object
#  1   Rented Bike Count         8760 non-null   int64
#  2   Hour                      8760 non-null   int64
#  3   Temperature(캜)            8760 non-null   float64
#  4   Humidity(%)               8760 non-null   int64
#  5   Wind speed (m/s)          8760 non-null   float64
#  6   Visibility (10m)          8760 non-null   int64
#  7   Dew point temperature(캜)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)   8760 non-null   float64
#  9   Rainfall(mm)              8760 non-null   float64
#  10  Snowfall (cm)             8760 non-null   float64
#  11  Seasons                   8760 non-null   object
#  12  Holiday                   8760 non-null   object
#  13  Functioning Day           8760 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.2+ KB

# %%
bike_df.columns = ['Date', 'Rented Bike Count', 'Hour', 'Temperature', 'Humidity',
       'Wind speed', 'Visibility', 'Dew point temperature',
       'Solar Radiation', 'Rainfall', 'Snowfall', 'Seasons',
       'Holiday', 'Functioning Day']

# %%
bike_df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature  Humidity  Wind speed  \
# 0  01/12/2017                254     0         -5.2        37         2.2
# 1  01/12/2017                204     1         -5.5        38         0.8
# 2  01/12/2017                173     2         -6.0        39         1.0
# 3  01/12/2017                107     3         -6.2        40         0.9
# 4  01/12/2017                 78     4         -6.0        36         2.3
#
#    Visibility  Dew point temperature  Solar Radiation  Rainfall  Snowfall  \
# 0        2000                  -17.6              0.0       0.0       0.0
# 1        2000                  -17.6              0.0       0.0       0.0
# 2        2000                  -17.7              0.0       0.0       0.0
# 3        2000                  -17.6              0.0       0.0       0.0
# 4        2000                  -18.6              0.0       0.0       0.0
#
#   Seasons     Holiday Functioning Day
# 0  Winter  No Holiday             Yes
# 1  Winter  No Holiday             Yes
# 2  Winter  No Holiday             Yes
# 3  Winter  No Holiday             Yes
# 4  Winter  No Holiday             Yes

# %%
sns.scatterplot(x='Temperature', y='Rented Bike Count', data=bike_df, alpha=0.3)
# Out:
# <Axes: xlabel='Temperature', ylabel='Rented Bike Count'>

# %%
sns.scatterplot(x='Wind speed', y='Rented Bike Count', data=bike_df, alpha=0.3)
# Out:
# <Axes: xlabel='Wind speed', ylabel='Rented Bike Count'>

# %%
sns.scatterplot(x='Visibility', y='Rented Bike Count', data=bike_df, alpha=0.3)
# Out:
# <Axes: xlabel='Visibility', ylabel='Rented Bike Count'>

# %%
sns.scatterplot(x='Hour', y='Rented Bike Count', data=bike_df, alpha=0.3)
# Out:
# <Axes: xlabel='Hour', ylabel='Rented Bike Count'>

# %%
bike_df.isna().sum()
# Out:
# Date                     0
# Rented Bike Count        0
# Hour                     0
# Temperature              0
# Humidity                 0
# Wind speed               0
# Visibility               0
# Dew point temperature    0
# Solar Radiation          0
# Rainfall                 0
# Snowfall                 0
# Seasons                  0
# Holiday                  0
# Functioning Day          0
# dtype: int64

# %%
bike_df['Date'] = pd.to_datetime(bike_df['Date'], format='%d/%m/%Y')
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   8760 non-null   datetime64[ns]
#  1   Rented Bike Count      8760 non-null   int64
#  2   Hour                   8760 non-null   int64
#  3   Temperature            8760 non-null   float64
#  4   Humidity               8760 non-null   int64
#  5   Wind speed             8760 non-null   float64
#  6   Visibility             8760 non-null   int64
#  7   Dew point temperature  8760 non-null   float64
#  8   Solar Radiation        8760 non-null   float64
#  9   Rainfall               8760 non-null   float64
#  10  Snowfall               8760 non-null   float64
#  11  Seasons                8760 non-null   object
#  12  Holiday                8760 non-null   object
#  13  Functioning Day        8760 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(4), object(3)
# memory usage: 958.2+ KB

# %%
bike_df['year'] = bike_df['Date'].dt.year
bike_df['month'] = bike_df['Date'].dt.month
bike_df['day'] = bike_df['Date'].dt.day
bike_df.head()
# Out:
#         Date  Rented Bike Count  Hour  Temperature  Humidity  Wind speed  \
# 0 2017-12-01                254     0         -5.2        37         2.2
# 1 2017-12-01                204     1         -5.5        38         0.8
# 2 2017-12-01                173     2         -6.0        39         1.0
# 3 2017-12-01                107     3         -6.2        40         0.9
# 4 2017-12-01                 78     4         -6.0        36         2.3
#
#    Visibility  Dew point temperature  Solar Radiation  Rainfall  Snowfall  \
# 0        2000                  -17.6              0.0       0.0       0.0
# 1        2000                  -17.6              0.0       0.0       0.0
# 2        2000                  -17.7              0.0       0.0       0.0
# 3        2000                  -17.6              0.0       0.0       0.0
# 4        2000                  -18.6              0.0       0.0       0.0
#
#   Seasons     Holiday Functioning Day  year  month  day
# 0  Winter  No Holiday             Yes  2017     12    1
# 1  Winter  No Holiday             Yes  2017     12    1
# 2  Winter  No Holiday             Yes  2017     12    1
# 3  Winter  No Holiday             Yes  2017     12    1
# 4  Winter  No Holiday             Yes  2017     12    1

# %%
plt.figure(figsize=(14, 4))
sns.lineplot(x='Date', y='Rented Bike Count', data=bike_df)
plt.xticks(rotation=45)
plt.show()

# %%
bike_df[bike_df['year'] == 2017].groupby('month')['Rented Bike Count'].mean()
# Out:
# month
# 12    249.099462
# Name: Rented Bike Count, dtype: float64

# %%
bike_df[bike_df['year'] == 2018].groupby('month')['Rented Bike Count'].mean()
# Out:
# month
# 1      201.620968
# 2      225.941964
# 3      511.551075
# 4      728.093056
# 5      950.387097
# 6     1245.676389
# 7      987.177419
# 8      876.192204
# 9      935.572222
# 10     874.563172
# 11     646.826389
# Name: Rented Bike Count, dtype: float64

# %%
bike_df['TimeOfDay'] = pd.cut(bike_df['Hour'], 
                            bins=[0, 5, 11, 17, 23], 
                            labels=['Dawn', 'Morning', 'Afternoon', 'Evening'],
                            include_lowest=True)

# %%
sns.barplot(x='Functioning Day', y='Rented Bike Count', data=bike_df)
# Out:
# <Axes: xlabel='Functioning Day', ylabel='Rented Bike Count'>

# %%
bike_df['Functioning Day'].value_counts()
# Out:
# Functioning Day
# Yes    8465
# No      295
# Name: count, dtype: int64

# %%
bike_df[bike_df['Functioning Day'] == 'No']
# Out:
#            Date  Rented Bike Count  Hour  Temperature  Humidity  Wind speed  \
# 3144 2018-04-11                  0     0         14.4        82         4.6
# 3145 2018-04-11                  0     1         13.6        81         3.6
# 3146 2018-04-11                  0     2         12.7        80         3.9
# 3147 2018-04-11                  0     3         11.6        81         3.1
# 3148 2018-04-11                  0     4         10.2        83         3.5
# ...         ...                ...   ...          ...       ...         ...
# 8251 2018-11-09                  0    19         11.9        71         2.7
# 8252 2018-11-09                  0    20         11.9        72         2.5
# 8253 2018-11-09                  0    21         11.4        74         1.9
# 8254 2018-11-09                  0    22         11.2        75         1.7
# 8255 2018-11-09                  0    23         10.9        76         1.2
#
#       Visibility  Dew point temperature  Solar Radiation  Rainfall  Snowfall  \
# 3144        1041                   11.3              0.0       0.0       0.0
# 3145         886                   10.3              0.0       0.0       0.0
# 3146         885                    9.3              0.0       0.0       0.0
# 3147         687                    8.4              0.0       0.0       0.0
# 3148         554                    7.4              0.0       0.0       0.0
# ...          ...                    ...              ...       ...       ...
# 8251         589                    6.7              0.0       0.0       0.0
# 8252         526                    7.0              0.0       0.0       0.0
# 8253         498                    6.9              0.0       0.0       0.0
# 8254         478                    6.9              0.0       0.0       0.0
# 8255         456                    6.8              0.0       0.0       0.0
#
#      Seasons     Holiday Functioning Day  year  month  day TimeOfDay
# 3144  Spring  No Holiday              No  2018      4   11      Dawn
# 3145  Spring  No Holiday              No  2018      4   11      Dawn
# 3146  Spring  No Holiday              No  2018      4   11      Dawn
# 3147  Spring  No Holiday              No  2018      4   11      Dawn
# 3148  Spring  No Holiday              No  2018      4   11      Dawn
# ...      ...         ...             ...   ...    ...  ...       ...
# 8251  Autumn  No Holiday              No  2018     11    9   Evening
# 8252  Autumn  No Holiday              No  2018     11    9   Evening
# 8253  Autumn  No Holiday              No  2018     11    9   Evening
# 8254  Autumn  No Holiday              No  2018     11    9   Evening
# 8255  Autumn  No Holiday              No  2018     11    9   Evening
#
# [295 rows x 18 columns]

# %%
bike_df = bike_df.drop('Date', axis=1)
bike_df.head()
# Out:
#    Rented Bike Count  Hour  Temperature  Humidity  Wind speed  Visibility  \
# 0                254     0         -5.2        37         2.2        2000
# 1                204     1         -5.5        38         0.8        2000
# 2                173     2         -6.0        39         1.0        2000
# 3                107     3         -6.2        40         0.9        2000
# 4                 78     4         -6.0        36         2.3        2000
#
#    Dew point temperature  Solar Radiation  Rainfall  Snowfall Seasons  \
# 0                  -17.6              0.0       0.0       0.0  Winter
# 1                  -17.6              0.0       0.0       0.0  Winter
# 2                  -17.7              0.0       0.0       0.0  Winter
# 3                  -17.6              0.0       0.0       0.0  Winter
# 4                  -18.6              0.0       0.0       0.0  Winter
#
#       Holiday Functioning Day  year  month  day TimeOfDay
# 0  No Holiday             Yes  2017     12    1      Dawn
# 1  No Holiday             Yes  2017     12    1      Dawn
# 2  No Holiday             Yes  2017     12    1      Dawn
# 3  No Holiday             Yes  2017     12    1      Dawn
# 4  No Holiday             Yes  2017     12    1      Dawn

# %%
bike_df.select_dtypes(exclude=['number']).columns.tolist()
# ['Seasons', 'Holiday', 'Functioning Day', 'TimeOfDay']
# Out:
# ['Seasons', 'Holiday', 'Functioning Day', 'TimeOfDay']

# %%
for i in bike_df.select_dtypes(exclude=['number']).columns.tolist():
    print(i, bike_df[i].nunique())

# Seasons 4
# Holiday 2
# Functioning Day 2
# TimeOfDay 4
# Out:
# Seasons 4
# Holiday 2
# Functioning Day 2
# TimeOfDay 4

# %%
bike_df = pd.get_dummies(bike_df, columns=bike_df.select_dtypes(exclude=['number']).columns.tolist(), drop_first=True)
bike_df.head()
# Out:
#    Rented Bike Count  Hour  Temperature  Humidity  Wind speed  Visibility  \
# 0                254     0         -5.2        37         2.2        2000
# 1                204     1         -5.5        38         0.8        2000
# 2                173     2         -6.0        39         1.0        2000
# 3                107     3         -6.2        40         0.9        2000
# 4                 78     4         -6.0        36         2.3        2000
#
#    Dew point temperature  Solar Radiation  Rainfall  Snowfall  ...  month  \
# 0                  -17.6              0.0       0.0       0.0  ...     12
# 1                  -17.6              0.0       0.0       0.0  ...     12
# 2                  -17.7              0.0       0.0       0.0  ...     12
# 3                  -17.6              0.0       0.0       0.0  ...     12
# 4                  -18.6              0.0       0.0       0.0  ...     12
#
#    day  Seasons_Spring  Seasons_Summer  Seasons_Winter  Holiday_No Holiday  \
# 0    1           False           False            True                True
# 1    1           False           False            True                True
# 2    1           False           False            True                True
# 3    1           False           False            True                True
# 4    1           False           False            True                True
#
#    Functioning Day_Yes  TimeOfDay_Morning  TimeOfDay_Afternoon  \
# 0                 True              False                False
# 1                 True              False                False
# 2                 True              False                False
# 3                 True              False                False
# 4                 True              False                False
#
#    TimeOfDay_Evening
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
#
# [5 rows x 21 columns]

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rented Bike Count      8760 non-null   int64
#  1   Hour                   8760 non-null   int64
#  2   Temperature            8760 non-null   float64
#  3   Humidity               8760 non-null   int64
#  4   Wind speed             8760 non-null   float64
#  5   Visibility             8760 non-null   int64
#  6   Dew point temperature  8760 non-null   float64
#  7   Solar Radiation        8760 non-null   float64
#  8   Rainfall               8760 non-null   float64
#  9   Snowfall               8760 non-null   float64
#  10  year                   8760 non-null   int32
#  11  month                  8760 non-null   int32
#  12  day                    8760 non-null   int32
#  13  Seasons_Spring         8760 non-null   bool
#  14  Seasons_Summer         8760 non-null   bool
#  15  Seasons_Winter         8760 non-null   bool
#  16  Holiday_No Holiday     8760 non-null   bool
#  17  Functioning Day_Yes    8760 non-null   bool
#  18  TimeOfDay_Morning      8760 non-null   bool
#  19  TimeOfDay_Afternoon    8760 non-null   bool
#  20  TimeOfDay_Evening      8760 non-null   bool
# dtypes: bool(8), float64(6), int32(3), int64(4)
# memory usage: 855.6 KB

# %%
correlation_matrix = bike_df.corr()
correlation_matrix
# Out:
#                        Rented Bike Count          Hour  Temperature  Humidity  \
# Rented Bike Count               1.000000  4.102573e-01     0.538558 -0.199780
# Hour                            0.410257  1.000000e+00     0.124114 -0.241644
# Temperature                     0.538558  1.241145e-01     1.000000  0.159371
# Humidity                       -0.199780 -2.416438e-01     0.159371  1.000000
# Wind speed                      0.121108  2.851967e-01    -0.036252 -0.336683
# Visibility                      0.199280  9.875348e-02     0.034794 -0.543090
# Dew point temperature           0.379788  3.054372e-03     0.912798  0.536894
# Solar Radiation                 0.261837  1.451309e-01     0.353505 -0.461919
# Rainfall                       -0.123074  8.714642e-03     0.050282  0.236397
# Snowfall                       -0.141804 -2.151645e-02    -0.218405  0.108183
# year                            0.215162  2.336763e-14     0.377796  0.035925
# month                           0.133514  1.749134e-15     0.216183  0.139875
# day                             0.022291  1.450952e-16     0.015645 -0.029044
# Seasons_Spring                  0.022888 -1.159917e-15     0.007960  0.015694
# Seasons_Summer                  0.296549  8.578102e-16     0.665846  0.192595
# Seasons_Winter                 -0.424925 -1.697335e-15    -0.738720 -0.238295
# Holiday_No Holiday              0.072338  1.289087e-16     0.055931  0.050278
# Functioning Day_Yes             0.203943  5.439377e-03    -0.050170 -0.020800
# TimeOfDay_Morning              -0.081115 -2.502173e-01    -0.075590  0.105659
# TimeOfDay_Afternoon             0.128639  2.502173e-01     0.172600 -0.365648
# TimeOfDay_Evening               0.322978  7.506519e-01     0.019061 -0.002143
#
#                        Wind speed  Visibility  Dew point temperature  \
# Rented Bike Count        0.121108    0.199280               0.379788
# Hour                     0.285197    0.098753               0.003054
# Temperature             -0.036252    0.034794               0.912798
# Humidity                -0.336683   -0.543090               0.536894
# Wind speed               1.000000    0.171507              -0.176486
# Visibility               0.171507    1.000000              -0.176630
# Dew point temperature   -0.176486   -0.176630               1.000000
# Solar Radiation          0.332274    0.149738               0.094381
# Rainfall                -0.019674   -0.167629               0.125597
# Snowfall                -0.003554   -0.121695              -0.150887
# year                    -0.003781    0.052381               0.336350
# month                   -0.156710    0.064874               0.242552
# day                     -0.031977   -0.101759               0.000153
# Seasons_Spring           0.083855   -0.187498               0.002056
# Seasons_Summer          -0.064698    0.061958               0.652378
# Seasons_Winter           0.109186    0.008616              -0.722366
# Holiday_No Holiday      -0.023017   -0.031773               0.066759
# Functioning Day_Yes      0.005037   -0.026000              -0.052837
# TimeOfDay_Morning       -0.157772   -0.087462              -0.015652
# TimeOfDay_Afternoon      0.354101    0.078511              -0.022475
# TimeOfDay_Evening        0.067050    0.065662               0.023274
#
#                        Solar Radiation  Rainfall  Snowfall  ...         month  \
# Rented Bike Count             0.261837 -0.123074 -0.141804  ...  1.335139e-01
# Hour                          0.145131  0.008715 -0.021516  ...  1.749134e-15
# Temperature                   0.353505  0.050282 -0.218405  ...  2.161826e-01
# Humidity                     -0.461919  0.236397  0.108183  ...  1.398748e-01
# Wind speed                    0.332274 -0.019674 -0.003554  ... -1.567102e-01
# Visibility                    0.149738 -0.167629 -0.121695  ...  6.487420e-02
# Dew point temperature         0.094381  0.125597 -0.150887  ...  2.425519e-01
# Solar Radiation               1.000000 -0.074290 -0.072301  ... -3.159544e-02
# Rainfall                     -0.074290  1.000000  0.008500  ...  1.195810e-02
# Snowfall                     -0.072301  0.008500  1.000000  ...  5.312091e-02
# year                          0.128086  0.027522 -0.206418  ... -4.836840e-01
# month                        -0.031595  0.011958  0.053121  ...  1.000000e+00
# day                          -0.002982 -0.001623  0.102077  ...  1.189318e-02
# Seasons_Spring                0.079974  0.017595 -0.099785  ... -4.253066e-01
# Seasons_Summer                0.128402  0.053928 -0.099785  ...  8.163275e-02
# Seasons_Winter               -0.178420 -0.058755  0.225875  ... -2.366106e-01
# Holiday_No Holiday            0.005077  0.014269  0.012591  ... -4.231911e-02
# Functioning Day_Yes          -0.007665  0.002055  0.032089  ... -1.352351e-01
# TimeOfDay_Morning             0.069047  0.013104  0.037729  ...  5.895956e-16
# TimeOfDay_Afternoon           0.627889 -0.008559 -0.013643  ...  3.970139e-16
# TimeOfDay_Evening            -0.318695  0.012940 -0.022516  ... -3.803076e-17
#
#                                 day  Seasons_Spring  Seasons_Summer  \
# Rented Bike Count      2.229091e-02    2.288822e-02    2.965494e-01
# Hour                   1.450952e-16   -1.159917e-15    8.578102e-16
# Temperature            1.564544e-02    7.959684e-03    6.658462e-01
# Humidity              -2.904392e-02    1.569416e-02    1.925949e-01
# Wind speed            -3.197744e-02    8.385451e-02   -6.469790e-02
# Visibility            -1.017585e-01   -1.874983e-01    6.195792e-02
# Dew point temperature  1.525311e-04    2.055888e-03    6.523778e-01
# Solar Radiation       -2.981839e-03    7.997416e-02    1.284017e-01
# Rainfall              -1.623338e-03    1.759519e-02    5.392817e-02
# Snowfall               1.020774e-01   -9.978516e-02   -9.978516e-02
# year                  -9.678711e-03    1.768562e-01    1.768562e-01
# month                  1.189318e-02   -4.253066e-01    8.163275e-02
# day                    1.000000e+00    7.682457e-03    7.682457e-03
# Seasons_Spring         7.682457e-03    1.000000e+00   -3.369963e-01
# Seasons_Summer         7.682457e-03   -3.369963e-01    1.000000e+00
# Seasons_Winter        -1.217579e-02   -3.320989e-01   -3.320989e-01
# Holiday_No Holiday     4.272067e-03    4.479057e-02    7.393239e-02
# Functioning Day_Yes    7.334856e-02    3.841275e-02    1.083703e-01
# TimeOfDay_Morning      6.404625e-17   -6.281246e-16    1.962805e-16
# TimeOfDay_Afternoon    7.243135e-17   -5.332116e-17    2.273227e-16
# TimeOfDay_Evening     -1.373560e-17    1.498183e-16   -4.894795e-16
#
#                        Seasons_Winter  Holiday_No Holiday  \
# Rented Bike Count       -4.249251e-01        7.233757e-02
# Hour                    -1.697335e-15        1.289087e-16
# Temperature             -7.387196e-01        5.593084e-02
# Humidity                -2.382952e-01        5.027765e-02
# Wind speed               1.091865e-01       -2.301677e-02
# Visibility               8.616224e-03       -3.177281e-02
# Dew point temperature   -7.223664e-01        6.675910e-02
# Solar Radiation         -1.784202e-01        5.077255e-03
# Rainfall                -5.875456e-02        1.426911e-02
# Snowfall                 2.258745e-01        1.259072e-02
# year                    -5.325406e-01        1.121635e-01
# month                   -2.366106e-01       -4.231911e-02
# day                     -1.217579e-02        4.272067e-03
# Seasons_Spring          -3.320989e-01        4.479057e-02
# Seasons_Summer          -3.320989e-01        7.393239e-02
# Seasons_Winter           1.000000e+00       -1.045574e-01
# Holiday_No Holiday      -1.045574e-01        1.000000e+00
# Functioning Day_Yes      1.067954e-01        2.762445e-02
# TimeOfDay_Morning       -2.959446e-16       -2.531791e-17
# TimeOfDay_Afternoon     -8.833690e-16        6.409210e-17
# TimeOfDay_Evening        1.926844e-16       -4.138899e-17
#
#                        Functioning Day_Yes  TimeOfDay_Morning  \
# Rented Bike Count                 0.203943      -8.111499e-02
# Hour                              0.005439      -2.502173e-01
# Temperature                      -0.050170      -7.558973e-02
# Humidity                         -0.020800       1.056593e-01
# Wind speed                        0.005037      -1.577725e-01
# Visibility                       -0.026000      -8.746190e-02
# Dew point temperature            -0.052837      -1.565173e-02
# Solar Radiation                  -0.007665       6.904654e-02
# Rainfall                          0.002055       1.310406e-02
# Snowfall                          0.032089       3.772862e-02
# year                             -0.056873      -2.511602e-16
# month                            -0.135235       5.895956e-16
# day                               0.073349       6.404625e-17
# Seasons_Spring                    0.038413      -6.281246e-16
# Seasons_Summer                    0.108370       1.962805e-16
# Seasons_Winter                    0.106795      -2.959446e-16
# Holiday_No Holiday                0.027624      -2.531791e-17
# Functioning Day_Yes               1.000000       1.096065e-03
# TimeOfDay_Morning                 0.001096       1.000000e+00
# TimeOfDay_Afternoon               0.002557      -3.333333e-01
# TimeOfDay_Evening                 0.002557      -3.333333e-01
#
#                        TimeOfDay_Afternoon  TimeOfDay_Evening
# Rented Bike Count             1.286388e-01       3.229776e-01
# Hour                          2.502173e-01       7.506519e-01
# Temperature                   1.726003e-01       1.906132e-02
# Humidity                     -3.656480e-01      -2.142835e-03
# Wind speed                    3.541009e-01       6.704981e-02
# Visibility                    7.851103e-02       6.566160e-02
# Dew point temperature        -2.247482e-02       2.327422e-02
# Solar Radiation               6.278890e-01      -3.186951e-01
# Rainfall                     -8.558828e-03       1.294048e-02
# Snowfall                     -1.364267e-02      -2.251644e-02
# year                          3.145293e-15       1.594929e-14
# month                         3.970139e-16      -3.803076e-17
# day                           7.243135e-17      -1.373560e-17
# Seasons_Spring               -5.332116e-17       1.498183e-16
# Seasons_Summer                2.273227e-16      -4.894795e-16
# Seasons_Winter               -8.833690e-16       1.926844e-16
# Holiday_No Holiday            6.409210e-17      -4.138899e-17
# Functioning Day_Yes           2.557484e-03       2.557484e-03
# TimeOfDay_Morning            -3.333333e-01      -3.333333e-01
# TimeOfDay_Afternoon           1.000000e+00      -3.333333e-01
# TimeOfDay_Evening            -3.333333e-01       1.000000e+00
#
# [21 rows x 21 columns]

# %%
target_corr = correlation_matrix['Rented Bike Count'].sort_values(ascending=False)
target_corr

# Rented Bike Count        1.000000
# Temperature              0.538558
# Hour                     0.410257
# Dew point temperature    0.379788
# TimeOfDay_Evening        0.322978
# Seasons_Summer           0.296549
# Solar Radiation          0.261837
# year                     0.215162
# Functioning Day_Yes      0.203943
# Visibility               0.199280
# month                    0.133514
# TimeOfDay_Afternoon      0.128639
# Wind speed               0.121108
# Holiday_No Holiday       0.072338
# Seasons_Spring           0.022888
# day                      0.022291
# TimeOfDay_Morning       -0.081115
# Rainfall                -0.123074
# Snowfall                -0.141804
# Humidity                -0.199780
# Seasons_Winter          -0.424925
# Name: Rented Bike Count, dtype: float64
# Out:
# Rented Bike Count        1.000000
# Temperature              0.538558
# Hour                     0.410257
# Dew point temperature    0.379788
# TimeOfDay_Evening        0.322978
# Seasons_Summer           0.296549
# Solar Radiation          0.261837
# year                     0.215162
# Functioning Day_Yes      0.203943
# Visibility               0.199280
# month                    0.133514
# TimeOfDay_Afternoon      0.128639
# Wind speed               0.121108
# Holiday_No Holiday       0.072338
# Seasons_Spring           0.022888
# day                      0.022291
# TimeOfDay_Morning       -0.081115
# Rainfall                -0.123074
# Snowfall                -0.141804
# Humidity                -0.199780
# Seasons_Winter          -0.424925
# Name: Rented Bike Count, dtype: float64

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.6-cp310-cp310-win_amd64.whl (9.6 MB)
#      ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#      - -------------------------------------- 0.4/9.6 MB 13.9 MB/s eta 0:00:01
#      --- ------------------------------------ 0.9/9.6 MB 13.8 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.3/9.6 MB 12.1 MB/s eta 0:00:01
#      ------- -------------------------------- 1.8/9.6 MB 12.4 MB/s eta 0:00:01
#      --------- ------------------------------ 2.2/9.6 MB 12.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 2.7/9.6 MB 12.1 MB/s eta 0:00:01
#      ------------ --------------------------- 3.1/9.6 MB 12.3 MB/s eta 0:00:01
#      -------------- ------------------------- 3.5/9.6 MB 12.5 MB/s eta 0:00:01
#      ---------------- ----------------------- 4.0/9.6 MB 12.7 MB/s eta 0:00:01
#      ------------------ --------------------- 4.4/9.6 MB 12.3 MB/s eta 0:00:01
#      -------------------- ------------------- 4.9/9.6 MB 12.4 MB/s eta 0:00:01
#      ---------------------- ----------------- 5.3/9.6 MB 12.6 MB/s eta 0:00:01
#      ------------------------ --------------- 5.8/9.6 MB 12.2 MB/s eta 0:00:01
#      ------------------------- -------------- 6.2/9.6 MB 12.3 MB/s eta 0:00:01
#      --------------------------- ------------ 6.6/9.6 MB 12.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 7.1/9.6 MB 12.5 MB/s eta 0:00:01
#      ------------------------------- -------- 7.5/9.6 MB 12.3 MB/s eta 0:00:01
#      --------------------------------- ------ 8.0/9.6 MB 12.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 8.4/9.6 MB 12.5 MB/s eta 0:00:01
#      ------------------------------------ --- 8.8/9.6 MB 12.6 MB/s eta 0:00:01
#      -------------------------------------- - 9.3/9.6 MB 12.3 MB/s eta 0:00:01
#      ---------------------------------------  9.6/9.6 MB 12.5 MB/s eta 0:00:01
#      ---------------------------------------- 9.6/9.6 MB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\suche\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\suche\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\suche\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.2.6)
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#      ---------------------------------------- 0.0/233.3 kB ? eta -:--:--
#      ------------------------------------- 233.3/233.3 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\suche\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\suche\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\suche\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\suche\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\suche\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.2 statsmodels-0.14.6
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
x = bike_df.drop('Rented Bike Count', axis=1)# 타겟 변수 제거
x = x.select_dtypes(include=['number']) # VIF는 수치형 데이터에 대해서만 계산 가능
x = x.astype(float) # VIF 계산을 위해 float 타입으로 변환
vif_df = pd.DataFrame({ 
    'Feature': x.columns,
    'VIF': [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]# 각 피처에 대한 VIF 계산
}).sort_values(by='VIF', ascending=False) # VIF 수치가 높은 순서대로 정렬
vif_df
# Out:
#                   Feature         VIF
# 9                    year  407.025112
# 1             Temperature  188.666573
# 2                Humidity  187.533688
# 5   Dew point temperature  126.954261
# 4              Visibility   10.788995
# 10                  month    5.108772
# 3              Wind speed    4.890096
# 0                    Hour    4.458880
# 11                    day    4.379818
# 6         Solar Radiation    2.904971
# 8                Snowfall    1.155412
# 7                Rainfall    1.103386

# %%
bike_df = bike_df.drop(['Dew_point_temperature', 'Hour', 'Humidity'], axis=1)
